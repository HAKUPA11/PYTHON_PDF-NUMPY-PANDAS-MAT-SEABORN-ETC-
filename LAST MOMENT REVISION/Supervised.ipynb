# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder , PolynomialFeatures
import warnings
from sklearn.linear_model import LinearRegression , LogisticRegression , LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,precision_score,recall_score,classification_report,accuracy_score,confusion_matrix,log_loss,roc_auc_score
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('titanic')

# %%
df.fillna({'age':df['age'].mean()},inplace=True)

# %%
df = df[['sex','age','fare','survived']]

# %%
le = LabelEncoder()
df['sex']=le.fit_transform(df['sex'])

# %%
x = df[['sex','age','fare']]
y= df['survived']

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.25)

# %%
model_nb = GaussianNB()

# %%
model_nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = model_nb.predict(x_test)

# %%
model_nb.score(x_test,y_test)
# Out:
# 0.7802690582959642

# %% [markdown]
# ####  Decision Tree

# %%
model_dt = DecisionTreeClassifier(random_state=42)

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt = model_dt.predict(x_test)

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.7757847533632287

# %% [markdown]
# #### SVC

# %%
model_svc = SVC()

# %%
model_svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred_svc = model_svc.predict(x_test)

# %%
mode_svc.score(x_test,y_test)
# Out:
# 0.6547085201793722

# %% [markdown]
# #### Neighbors

# %%
model_knn = KNeighborsClassifier(n_neighbors=3)

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn = model_knn.predict(x_test)

# %%
model_knn.score(x_test,y_test)
# Out:
# 0.6995515695067265

# %%
confusion_matrix(y_test,y_pred_svc)
# Out:
# array([[124,  13],
#        [ 64,  22]])

# %%
1 - mean_absolute_error(y_test,y_pred_svc)
# Out:
# 0.6547085201793722

# %%
roc_auc_score(y_pred_knn,y_test)
# Out:
# np.float64(0.6815765765765766)
