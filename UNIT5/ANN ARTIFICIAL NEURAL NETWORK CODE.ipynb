# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# https://www.youtube.com/watch?v=ydzFSLDmHmE&t=428s   coding ANN implementation refference

# %% [markdown]
# ![img1.png](attachment:img1.png)
#
# ![img2.png](attachment:img2.png)
#
# inside our hidden layer two very important calculations takes place
# first : we calculate the value of 'Z' which is= input * weight + bias
# i.e Z = n1w1 + n2w2 + n3w3 + b1
#
# second : to apply "activation function" we have few activation fxns but here we discuss/use sigmoid fxn
# [sigmoid fxn is an activation fxn which gives value from 0 to 1]
#
# ![img3.png](attachment:img3.png)

# %% [markdown]
# whenever we assign some weights we do that by some weight initialization technique , we will discuss that later on. For know let us have weight=[0.01, 0.02, 0.03] and bias=0.001
#
# ![img4.png](attachment:img4.png)
#
# look at the updated diagram
# ![img5.png](attachment:img5.png)
#
# ![img6.png](attachment:img6.png)

# %% [markdown]
# we can see that there is a loss of 0.49, we should reduce it to nearly 0.0something, we can do that later but now we shall look at the implementation
