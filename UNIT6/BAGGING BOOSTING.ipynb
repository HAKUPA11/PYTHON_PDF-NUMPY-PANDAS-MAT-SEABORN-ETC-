# %% [markdown]
# ![ph1.png](attachment:ph1.png)

# %% [markdown]
# ![ph2.png](attachment:ph2.png)

# %% [markdown]
# ![ph3.png](attachment:ph3.png)

# %% [markdown]
# we have different training models and have a dataset D now we pass few of the data say d' to model m1, d'' to m2, d''' to m3 and so on, then we calculate the mean of each model then we calculate the mean of all these calculated means.
# that will be the accuracy score of the training data
#
# in case of test data lets say each of the model gives certain value then we have to select the value via "
# maximum voting"

# %% [markdown]
# now we have seen that in case of bagging all the models were connected paralley but in case of boosting all models are connected sequentially
#
# bagging is also called "weak learners"
#
# we pass the training data via first model now that model will give some wrong prediction that wrong prediction is passed through next model again this model will predict some wrong , again this will get trained in other model and this process goes on. Now all of these model individually are weak learners but when combined, it becomes strong learners
#
#
# ![ph4.png](attachment:ph4.png)
