# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_openml

# %%
b_cancer= fetch_openml(name="Breast-cancer", version=1, as_frame=True)
df=b_cancer.frame
df.head()
# Out:
#      age menopause tumor-size inv-nodes node-caps deg-malig breast  \
# 0  40-49   premeno      15-19       0-2       yes         3  right
# 1  50-59      ge40      15-19       0-2        no         1  right
# 2  50-59      ge40      35-39       0-2        no         2   left
# 3  40-49   premeno      35-39       0-2       yes         3  right
# 4  40-49   premeno      30-34       3-5       yes         2   left
#
#   breast-quad irradiat                 Class
# 0     left_up       no     recurrence-events
# 1     central       no  no-recurrence-events
# 2    left_low       no     recurrence-events
# 3    left_low      yes  no-recurrence-events
# 4    right_up       no     recurrence-events

# %%
print(df.isnull().sum())
# Out:
# age            0
# menopause      0
# tumor-size     0
# inv-nodes      0
# node-caps      8
# deg-malig      0
# breast         0
# breast-quad    1
# irradiat       0
# Class          0
# dtype: int64

# %%
df.describe()
# Out:
#           age menopause tumor-size inv-nodes node-caps deg-malig breast  \
# count     286       286        286       286       278       286    286
# unique      6         3         11         7         2         3      2
# top     50-59   premeno      30-34       0-2        no         2   left
# freq       96       150         60       213       222       130    152
#
#        breast-quad irradiat                 Class
# count          285      286                   286
# unique           5        2                     2
# top       left_low       no  no-recurrence-events
# freq           110      218                   201

# %%
df.fillna({'node-caps':"yes", 'breast-quad':'left_up'}, inplace=True)

# %%
X=df[["breast", "menopause"]]
y=df["deg-malig"]

# %%
le=LabelEncoder()

df["breast"]=le.fit_transform(df["breast"])
df["menopause"]=le.fit_transform(df["menopause"])

X_train, X_test, y_train, y_test=train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
scaler=StandardScaler()
# le=LabelEncoder()
# ohc=OneHotEncoder()
# df["breast"]=ohc.fit_transform(df["breast"])
# df["menopause"]=ohc.fit_transform(df["menopause"])

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_53736\1537555281.py in ?()
#       3 # ohc=OneHotEncoder()
#       4 # df["breast"]=ohc.fit_transform(df["breast"])
#       5 # df["menopause"]=ohc.fit_transform(df["menopause"])
#       6
# ----> 7 X_train = scaler.fit_transform(X_train)
#       8 X_test = scaler.transform(X_test)
#
# ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
# ...

# %%
model=SVC(kernel="linear")
model.fit(X_train, y_train)

y_pred=model.predict()
